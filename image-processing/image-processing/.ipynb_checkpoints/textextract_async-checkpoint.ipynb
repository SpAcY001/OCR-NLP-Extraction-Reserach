# %%
import boto3
import time
import sagemaker

# %%
role = sagemaker.get_execution_role()
region = boto3.Session().region_name
sagemaker_session = sagemaker.Session()
client = boto3.client('textract',region_name=region,aws_access_key_id='AKIARU3MIISFVHPQBHLV',aws_secret_access_key='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')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml

# %%
def start_job(client, s3_bucket_name, object_name):
    response = None
    response = client.start_document_text_detection(
        DocumentLocation={
            'S3Object': {
                'Bucket': s3_bucket_name,
                'Name': object_name
            }}
    )

    return response["JobId"]

# %%
def is_job_complete(client, job_id):
    time.sleep(1)
    response = client.get_document_text_detection(JobId=job_id)
    status = response["JobStatus"]
    print("Job status: {}".format(status))

    while(status == "IN_PROGRESS"):
        time.sleep(1)
        response = client.get_document_text_detection(JobId=job_id)
        status = response["JobStatus"]
        print("Job status: {}".format(status))

    return status

# %%
def get_job_results(client, job_id):
    pages = []
    time.sleep(1)
    response = client.get_document_text_detection(JobId=job_id)
    pages.append(response)
    print("Resultset page received: {}".format(len(pages)))
    next_token = None
    if 'NextToken' in response:
        next_token = response['NextToken']

    while next_token:
        time.sleep(1)
        response = client.\
            get_document_text_detection(JobId=job_id, NextToken=next_token)
        pages.append(response)
        print("Resultset page received: {}".format(len(pages)))
        next_token = None
        if 'NextToken' in response:
            next_token = response['NextToken']

    return pages

# %%
filetexts  = dict()

# %%
s3_bucket_name = "s3sagemakerbucket"
document_name = "DUBAI ELECTRICITY AND WATER/BG1110005292.pdf"
file="BG1110005292.pdf"

client = boto3.client('textract',region_name=region,aws_access_key_id='AKIARU3MIISFVHPQBHLV',aws_secret_access_key='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')

job_id = start_job(client, s3_bucket_name, document_name)
print("Started job with id: {}".format(job_id))
if is_job_complete(client, job_id):
    response = get_job_results(client, job_id)

# print(response)

# for result_page in response:
#     for item in result_page["Blocks"]:
#         if item["BlockType"] == "LINE":
#             print('\033[94m' + item["Text"] + '\033[0m')
# Out:
# Started job with id: 7961cc0925230954389734d008906e21be8b020dfdf7782d1c999aff47707568
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page received: 1

# %%
lines=[]
for result_page in response:
    for item in result_page["Blocks"]:
        if item["BlockType"] == "LINE":
            print(item["Text"])
            lines.append(item["Text"])
filetexts[file] = lines
# Out:
# 013442
# HSBC AX
# Untitled
# HSBC BANK EGYPT
# P.O.BOX 126D ZAMALEK
# DATE OF ISSUE:
# CAIRO
# 15DEC2020
# OUR GUARANTEE NO: PEBCA0207789
# M/S:
# COLAS RAIL EGYPT
# 33 FALAKY ST, BAB EL
# LOUK, CAIRO, EGYPT
# AMOUNT: EUR
# 54,275.00
# EXPIRY DATE: 15DEC2021
# DEAR SIRS,
# PERFORMANCE LETTER OF GUARANTEE NO. 207789
# WE HEREBY GUARANTEE MESSRS. SCHNEIDER ELECTRIC EGYPT
# (HEREINAFTER CALLED APPLICANTS).
# TO THE EXTENT OF EUR 54,275.00 (SAY FIFTY FOUR THOUSAND TWO
# HUNDRED AND SEVENTY FIVE EUROS ONLY).
# IN RESPECT OF : CONTRACT NUMBER 20001824 DATED 07/12/2020 FOR
# SUPPLYING LV PRIMARY CABINETS FOR PH3C (LPS) , PROJECT :- CAIRO
# METRO LINE 3 PHASE 3.
# AND WE UNDERTAKE TO PAY THIS SUM TO YOU ON YOUR FIRST WRITTEN
# DEMAND, NOTWITHSTANDING ANY CONTESTATION BY THE APPLICANTS.
# OUR MAXIMUM LIABILITY UNDER THIS GUARANTEE INCLUSIVE OF ANY
# INTEREST, SHALL IN NO EVENT EXCEED IN AGGREGATE : EUR 54,275.00
# THIS LETTER OF GUARANTEE HOLDS GOOD UNTIL THE 15/12/2021
# CONSEQUENTLY, ANY CLAIM IN RESPECT THEREOF SHOULD BE MADE TO US
# IN WRITING AT OUR GTRF DEPARTMENT LOCATED AT THE HEAD OFFICE,
# 306 CORNICHE EL NIL STREET, MAADI, CAIRO, EGYPT WITHIN OUR
# BANKING BUSINESS HOURS IN THIS OFFICE ON OR BEFORE 15 DECEMBER
# 2021 AT THE LATEST.
# SHOULD WE RECEIVE NO CLAIM FROM YOU BY THAT DATE, OUR LIABILITY
# WILL CEASE (IPSO FACTO) AND THE PRESENT L/G WILL DEFINITELY
# BECOME NULL AND VOID WHETHER OR NOT THE ORIGINAL L/G RETURNED TO
# US.
# WE CONFIRM THAT THE SAID GUARANTEE HAS BEEN ISSUED BY US, WITHIN
# THE AUTHORIZED LIMIT TO US FOR ISSUANCE OF LETTERS OF GUARANTEE
# FROM THE CENTRAL BANK OF EGYPT.
# PLEASE RETURN TO US THIS LETTER OF GUARANTEE ON EXPIRY DATE FOR
# OUR RECORDS.
# YOURS FAITHFULLY,
# .
# Head Office & Cairo Branch
# 306, Corniche El Nil - Maadi, Cairo A.R.E.
# Page 1
# was
# Box 124 Maadi
# Il
# CITIBANK
# CHENK NA
# 20
# 2015 AUG 20 P 4: 50
# LODGEMENT MEMO
# TO: CUSTODIAN
# GLOBAL TRANSACTIONS
# FROM Ahish Singhal
# Scanned ref # 50Mbat CONTENTS NOT VERIFIED
# SERVICES
# CUSTOMER- NAME: Ameroys Indipful be
# DATE: 18/8/1-
# PRODUCT: DOCARCHIVE
# The following documents are being lodged for safekeeping. I have verified the same & have found them to be in order.
# The facility to which the document pertains to has also been indicated.
# DOCUMENT
# Dated
# Amount
# CODE
# Facility
# Board Resolution
# BOARD
# Shareholder Resolution
# SHBR
# Promissory Note & Letter of Continuity
# PNLOC
# Unsecured Working Capital agreement
# UNSWORKCAP
# Working Capital Consortium Agreement
# WCCONSAGMT
# Joint Deed of Hypothecation
# HYPJTDEED
# Inter-se Agreement
# INTERSE
# Supplemental Agreement
# SUPPAGMT
# Good Security agreement
# GSA
# Hypothecation Agreement
# HYPOTH
# Pledge agreement
# PLEDGE
# Fixed Deposit advice
# FD ADVICE
# Commercial card agreement
# COMMCARD
# Term Loan Agreement
# TERMAGMT
# ECB LOAN
# ECB
# FCNR(B) Loan Agreement
# FCNRAGMT
# ParriPassu letter from bank:
# PARRIPASSU
# CA Certificate/Certificate
# CACERT
# Form CHGI
# FORM CHGI
# Letters
# LETTER
# Form CHG4
# FORM CHG4
# Corporate Guarantee
# CORPGTEE
# Letter of Support
# LOS
# Letter of Awareness
# LOA
# Letter of Comfort
# LOC
# Memorandum of entries
# MOE
# MOA & AOA
# MOA AOA
# Certificate of Incorporation (Name Change)
# COI
# ISDA (ISDA agreement, Schedule, RDS,
# ISDA
# legal opinion and BR)
# Power of Attorney
# POA
# Deed of Confirmation / Merger documents
# DEED
# OTHERS (mention description of document)
# OTHERS
# Doc for Facility : PSE/CC/WCDL/TERMLOAN OMNIBUS/EXPORTS/LC/ OTHERS (specify)
# IS DOCUMENT PER STANDARD AGREEMENT (If No attach approval for changes) :
# ( Affirms completeness and adequacy of documents lodged
# Big
# RISIGNATURE
# Internal

# %%
lines
# Out:
# ['013442',
#  'HSBC AX',
#  'Untitled',
#  'HSBC BANK EGYPT',
#  'P.O.BOX 126D ZAMALEK',
#  'DATE OF ISSUE:',
#  'CAIRO',
#  '15DEC2020',
#  'OUR GUARANTEE NO: PEBCA0207789',
#  'M/S:',
#  'COLAS RAIL EGYPT',
#  '33 FALAKY ST, BAB EL',
#  'LOUK, CAIRO, EGYPT',
#  'AMOUNT: EUR',
#  '54,275.00',
#  'EXPIRY DATE: 15DEC2021',
#  'DEAR SIRS,',
#  'PERFORMANCE LETTER OF GUARANTEE NO. 207789',
#  'WE HEREBY GUARANTEE MESSRS. SCHNEIDER ELECTRIC EGYPT',
#  '(HEREINAFTER CALLED APPLICANTS).',
#  'TO THE EXTENT OF EUR 54,275.00 (SAY FIFTY FOUR THOUSAND TWO',
#  'HUNDRED AND SEVENTY FIVE EUROS ONLY).',
#  'IN RESPECT OF : CONTRACT NUMBER 20001824 DATED 07/12/2020 FOR',
#  'SUPPLYING LV PRIMARY CABINETS FOR PH3C (LPS) , PROJECT :- CAIRO',
#  'METRO LINE 3 PHASE 3.',
#  'AND WE UNDERTAKE TO PAY THIS SUM TO YOU ON YOUR FIRST WRITTEN',
#  'DEMAND, NOTWITHSTANDING ANY CONTESTATION BY THE APPLICANTS.',
#  'OUR MAXIMUM LIABILITY UNDER THIS GUARANTEE INCLUSIVE OF ANY',
#  'INTEREST, SHALL IN NO EVENT EXCEED IN AGGREGATE : EUR 54,275.00',
#  'THIS LETTER OF GUARANTEE HOLDS GOOD UNTIL THE 15/12/2021',
#  'CONSEQUENTLY, ANY CLAIM IN RESPECT THEREOF SHOULD BE MADE TO US',
#  'IN WRITING AT OUR GTRF DEPARTMENT LOCATED AT THE HEAD OFFICE,',
#  '306 CORNICHE EL NIL STREET, MAADI, CAIRO, EGYPT WITHIN OUR',
#  'BANKING BUSINESS HOURS IN THIS OFFICE ON OR BEFORE 15 DECEMBER',
#  '2021 AT THE LATEST.',
#  'SHOULD WE RECEIVE NO CLAIM FROM YOU BY THAT DATE, OUR LIABILITY',
#  'WILL CEASE (IPSO FACTO) AND THE PRESENT L/G WILL DEFINITELY',
#  'BECOME NULL AND VOID WHETHER OR NOT THE ORIGINAL L/G RETURNED TO',
#  'US.',
#  'WE CONFIRM THAT THE SAID GUARANTEE HAS BEEN ISSUED BY US, WITHIN',
#  'THE AUTHORIZED LIMIT TO US FOR ISSUANCE OF LETTERS OF GUARANTEE',
#  'FROM THE CENTRAL BANK OF EGYPT.',
#  'PLEASE RETURN TO US THIS LETTER OF GUARANTEE ON EXPIRY DATE FOR',
#  'OUR RECORDS.',
#  'YOURS FAITHFULLY,',
#  '.',
#  'Head Office & Cairo Branch',
#  '306, Corniche El Nil - Maadi, Cairo A.R.E.',
#  'Page 1',
#  'was',
#  'Box 124 Maadi',
#  'Il',
#  'CITIBANK',
#  'CHENK NA',
#  '20',
#  '2015 AUG 20 P 4: 50',
#  'LODGEMENT MEMO',
#  'TO: CUSTODIAN',
#  'GLOBAL TRANSACTIONS',
#  'FROM Ahish Singhal',
#  'Scanned ref # 50Mbat CONTENTS NOT VERIFIED',
#  'SERVICES',
#  'CUSTOMER- NAME: Ameroys Indipful be',
#  'DATE: 18/8/1-',
#  'PRODUCT: DOCARCHIVE',
#  'The following documents are being lodged for safekeeping. I have verified the same & have found them to be in order.',
#  'The facility to which the document pertains to has also been indicated.',
#  'DOCUMENT',
#  'Dated',
#  'Amount',
#  'CODE',
#  'Facility',
#  'Board Resolution',
#  'BOARD',
#  'Shareholder Resolution',
#  'SHBR',
#  'Promissory Note & Letter of Continuity',
#  'PNLOC',
#  'Unsecured Working Capital agreement',
#  'UNSWORKCAP',
#  'Working Capital Consortium Agreement',
#  'WCCONSAGMT',
#  'Joint Deed of Hypothecation',
#  'HYPJTDEED',
#  'Inter-se Agreement',
#  'INTERSE',
#  'Supplemental Agreement',
#  'SUPPAGMT',
#  'Good Security agreement',
#  'GSA',
#  'Hypothecation Agreement',
#  'HYPOTH',
#  'Pledge agreement',
#  'PLEDGE',
#  'Fixed Deposit advice',
#  'FD ADVICE',
#  'Commercial card agreement',
#  'COMMCARD',
#  'Term Loan Agreement',
#  'TERMAGMT',
#  'ECB LOAN',
#  'ECB',
#  'FCNR(B) Loan Agreement',
#  'FCNRAGMT',
#  'ParriPassu letter from bank:',
#  'PARRIPASSU',
#  'CA Certificate/Certificate',
#  'CACERT',
#  'Form CHGI',
#  'FORM CHGI',
#  'Letters',
#  'LETTER',
#  'Form CHG4',
#  'FORM CHG4',
#  'Corporate Guarantee',
#  'CORPGTEE',
#  'Letter of Support',
#  'LOS',
#  'Letter of Awareness',
#  'LOA',
#  'Letter of Comfort',
#  'LOC',
#  'Memorandum of entries',
#  'MOE',
#  'MOA & AOA',
#  'MOA AOA',
#  'Certificate of Incorporation (Name Change)',
#  'COI',
#  'ISDA (ISDA agreement, Schedule, RDS,',
#  'ISDA',
#  'legal opinion and BR)',
#  'Power of Attorney',
#  'POA',
#  'Deed of Confirmation / Merger documents',
#  'DEED',
#  'OTHERS (mention description of document)',
#  'OTHERS',
#  'Doc for Facility : PSE/CC/WCDL/TERMLOAN OMNIBUS/EXPORTS/LC/ OTHERS (specify)',
#  'IS DOCUMENT PER STANDARD AGREEMENT (If No attach approval for changes) :',
#  '( Affirms completeness and adequacy of documents lodged',
#  'Big',
#  'RISIGNATURE',
#  'Internal']

# %%
for file, text in filetexts.items():
    file2 = file.split('.')[0]
    file2 = file.replace('.pdf','').replace('.','')
    with open(f'{file2}.txt', 'w', encoding = "utf-8") as outfile:
        for line in lines:
            outfile.write(line + '\n')
        outfile.close()
